# %% [markdown]
# <a href="https://colab.research.google.com/github/samerac123/samer_final_project/blob/main/Final_Project__oil__prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
olive_oil_df = pd.read_csv("//content/shouf_olive_oil_dataset_FINAL.csv")

# %%
olive_oil_df.head()
# Out:
#    Year            Field_ID  Altitude_m  Annual_Rainfall_mm_year  \
# 0  2015  Ammatour_1_Field_1       738.0                   1112.5
# 1  2015  Ammatour_2_Field_1       701.7                   1112.5
# 2  2015  Ammatour_1_Field_2       746.7                   1112.5
# 3  2015  Ammatour_2_Field_2       796.8                   1137.5
# 4  2015  Ammatour_1_Field_3       696.2                   1087.5
#
#    Spring_Rainfall_mm_season  Summer_Max_Temp_C_avg  Frost_Days_count  \
# 0                      247.5                   32.4             31.75
# 1                      247.5                   32.4             31.75
# 2                      247.5                   32.4             31.75
# 3                      262.5                   32.2             39.25
# 4                      232.5                   32.6             24.25
#
#    Irrigation_L_per_tree  Tree_Age_Years  Tree_Density_per_hectare  \
# 0              400.00000              53                       344
# ...

# %%
olive_oil_df.describe()
# Out:
#               Year  Altitude_m  Annual_Rainfall_mm_year  \
# count   200.000000  200.000000               200.000000
# mean   2019.500000  699.765000              1119.374500
# std       2.879489   53.712582               124.228057
# min    2015.000000  600.000000               526.300000
# 25%    2017.000000  672.450000              1087.500000
# 50%    2019.500000  696.200000              1142.500000
# 75%    2022.000000  738.650000              1187.500000
# max    2024.000000  800.000000              1287.500000
#
#        Spring_Rainfall_mm_season  Summer_Max_Temp_C_avg  Frost_Days_count  \
# count                 200.000000             200.000000        200.000000
# mean                  247.439000              32.340500         26.882000
# std                    25.522755               0.949589          7.835649
# min                   127.600000              25.900000          8.400000
# 25%                   232.500000              31.900000         21.250000
# ...

# %%
olive_oil_df.Irrigation_L_per_tree.unique()
# Out:
# array([400.        ,   0.        , 712.49707027, 900.        ,
#        524.99414053, 431.24267567, 775.00585947])

# %%
olive_oil_df.Soil_Type.unique()
# Out:
# array(['Clay', 'Loam', 'Sandy_Loam'], dtype=object)

# %%
import seaborn as sns

# %%
sns.violinplot(x='Olives_Produced_kg_per_hectare', y='Soil_Type', data=olive_oil_df)
# Out:
# <Axes: xlabel='Olives_Produced_kg_per_hectare', ylabel='Soil_Type'>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
plt.figure(figsize=(10,5))
sns.heatmap(olive_oil_df.select_dtypes(include=np.number).corr(),annot=True,vmin=0,vmax=1,cmap='viridis')
# Out:
# <Axes: >
